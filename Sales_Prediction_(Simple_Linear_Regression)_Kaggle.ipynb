# %%
import copy, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.set_printoptions(precision=2)
from sklearn.metrics import mean_squared_error
# Out:
# Running cells with 'Python 3.12.1' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ASUS/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
data = pd.read_csv("/content/advertising.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
x_train = data.iloc[:,:3].values
y_train = data.iloc[:,3].values

# %%
b_init = 0
w_init = np.random.random(3)

# %%
# def predict_single_loop(x, w, b):
#       """
#       single predict using linear regression

#       Args:
#         x (ndarray): Shape (n,) example with multiple features
#         w (ndarray): Shape (n,) model parameters
#         b (scalar):  model parameter

#       Returns:
#         p (scalar):  prediction
#       """
#       n = x.shape[0]
#       p = 0
#       for i in range(n):
#         p_i = x[i] * w[i]
#         p += p_i
#       p += b
#       return p

# %%
# x_vec = x_train[0,:]
# print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# f_wb = predict_single_loop(x_vec, w_init, b_init)
# print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")

# %%
def compute_cost(x, y, w, b):
    """
    compute cost
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      b (scalar)       : model parameter

    Returns:
      cost (scalar): cost
    """
    m = x.shape[0]
    cost = 0.0
    for i in range(m):
      f_wb_i = np.dot(x[i], w) + b
      cost += (f_wb_i - y[i])**2

    cost /= (2*m)
    return cost

# %%
cost = compute_cost(x_train, y_train, w_init, b_init)
print(f"Cost at optimal w: {cost}")
# Out:
# Cost at optimal w: 2644.7669058608653

# %%
def compute_gradient(x, y, w, b):
    """
    Computes the gradient for linear regression
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      b (scalar)       : model parameter

    Returns:
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w.
      dj_db (scalar):       The gradient of the cost w.r.t. the parameter b.
    """
    m, n = x.shape
    dj_dw = np.zeros((n,))
    dj_db = 0.0

    for i in range(m):
      err = (np.dot(x[i], w) + b) - y[i]
      for j in range(n):
        dj_dw[j] = dj_dw[j] + err*x[i, j]
      dj_db = dj_db + err

    dj_dw /= m
    dj_db /= m

    return dj_db, dj_dw

# %%
#Compute and display gradient
tmp_dj_db, tmp_dj_dw = compute_gradient(x_train, y_train, w_init, b_init)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: \n {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: 64.73744096186928
# dj_dw at initial w,b:
#  [12252.64  1656.45  2132.21]

# %%
def gradient_descent(x, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters):
      """
      Performs batch gradient descent to learn w and b. Updates w and b by taking
      num_iters gradient steps with learning rate alpha

      Args:
        X (ndarray (m,n))   : Data, m examples with n features
        y (ndarray (m,))    : target values
        w_in (ndarray (n,)) : initial model parameters
        b_in (scalar)       : initial model parameter
        cost_function       : function to compute cost
        gradient_function   : function to compute the gradient
        alpha (float)       : Learning rate
        num_iters (int)     : number of iterations to run gradient descent

      Returns:
        w (ndarray (n,)) : Updated values of parameters
        b (scalar)       : Updated value of parameter
        """
      J_history = []
      w = copy.deepcopy(w_in)
      b = b_in

      for i in range(num_iters):
        dj_db, dj_dw = gradient_function(x, y, w, b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

      if i<100000:
        J_history.append(cost_function(x, y, w, b))

      if i%math.ceil(num_iters/10) == 0:
        print(f"Iteration {i:4d}: cost {J_history[-1]: 8.2f}")

      return w, b, J_history

# %%
# initialize parameters
initial_w = np.zeros_like(w_init)
initial_b = 0.
# some gradient descent settings
iterations = 1000
alpha = 5.0e-7
# run gradient descent
w_final, b_final, J_hist = gradient_descent(x_train, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient,
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = x_train.shape
y_pred = np.zeros(m)

for i in range(m):
    estimate = np.dot(x_train[i], w_final) + b_final
    y_pred[i] = estimate
    print(f"prediction: {estimate:0.2f}, target value: {y_train[i]}")


rmse = math.sqrt(mean_squared_error(y_pred, y_train))
print(rmse)
# Out:
# b,w found by gradient descent: 0.00,[0.08 0.03 0.03]
# prediction: 22.42, target value: 22.1
# prediction: 6.48, target value: 10.4
# prediction: 5.27, target value: 12.0
# prediction: 15.75, target value: 16.5
# prediction: 17.11, target value: 17.9
# prediction: 4.87, target value: 7.2
# prediction: 6.60, target value: 11.8
# prediction: 10.89, target value: 13.2
# prediction: 0.81, target value: 4.8
# prediction: 17.15, target value: 15.6
# prediction: 6.41, target value: 12.6
# prediction: 18.52, target value: 17.4
# prediction: 5.33, target value: 9.2
# prediction: 8.48, target value: 13.7
# prediction: 19.35, target value: 19.0
# prediction: 19.37, target value: 22.4
# prediction: 10.58, target value: 12.5
# prediction: 26.23, target value: 24.4
# prediction: 6.97, target value: 11.3
# prediction: 13.50, target value: 14.6
# prediction: 20.59, target value: 18.0
# prediction: 20.39, target value: 17.5
# prediction: 3.27, target value: 5.6
# prediction: 20.13, target value: 20.5
# prediction: 6.14, target value: 9.7
# prediction: 22.29, target value: 17.0
# prediction: 13.11, target value: 15.0
# prediction: 20.98, target value: 20.9
# prediction: 22.05, target value: 18.9
# prediction: 7.68, target value: 10.5
# prediction: 26.37, target value: 21.4
# prediction: 11.12, target value: 11.9
# prediction: 9.01, target value: 13.2
# prediction: 22.43, target value: 17.4
# prediction: 8.13, target value: 11.9
# prediction: 24.21, target value: 17.8
# prediction: 23.50, target value: 25.4
# prediction: 9.31, target value: 14.7
# prediction: 5.60, target value: 10.1
# prediction: 21.01, target value: 21.5
# prediction: 18.38, target value: 16.6
# prediction: 16.91, target value: 17.1
# prediction: 25.03, target value: 20.7
# prediction: 18.10, target value: 17.9
# prediction: 4.37, target value: 8.5
# prediction: 16.14, target value: 16.1
# prediction: 8.87, target value: 10.6
# prediction: 21.66, target value: 23.2
# prediction: 20.79, target value: 19.8
# prediction: 7.10, target value: 9.7
# prediction: 17.61, target value: 16.4
# prediction: 8.66, target value: 10.7
# prediction: 20.44, target value: 22.6
# prediction: 18.47, target value: 21.2
# prediction: 23.01, target value: 20.2
# prediction: 19.95, target value: 23.7
# prediction: 2.93, target value: 5.5
# prediction: 12.35, target value: 13.2
# prediction: 20.19, target value: 23.8
# prediction: 18.56, target value: 18.4
# prediction: 5.16, target value: 8.1
# prediction: 24.66, target value: 24.2
# prediction: 21.02, target value: 20.7
# prediction: 9.69, target value: 14.0
# prediction: 13.14, target value: 16.0
# prediction: 5.99, target value: 11.3
# prediction: 3.49, target value: 11.0
# prediction: 12.23, target value: 13.4
# prediction: 20.73, target value: 18.9
# prediction: 20.14, target value: 22.3
# prediction: 18.62, target value: 18.3
# prediction: 10.53, target value: 12.4
# prediction: 3.96, target value: 8.8
# prediction: 11.83, target value: 11.0
# prediction: 18.74, target value: 17.0
# prediction: 5.84, target value: 8.7
# prediction: 2.99, target value: 6.9
# prediction: 11.30, target value: 14.2
# prediction: 1.77, target value: 5.3
# prediction: 10.52, target value: 11.0
# prediction: 7.90, target value: 11.8
# prediction: 20.99, target value: 17.3
# prediction: 7.93, target value: 11.3
# prediction: 8.29, target value: 13.6
# prediction: 20.06, target value: 21.7
# prediction: 18.62, target value: 20.2
# prediction: 7.71, target value: 12.0
# prediction: 12.54, target value: 16.0
# prediction: 10.54, target value: 12.9
# prediction: 12.32, target value: 16.7
# prediction: 11.47, target value: 14.0
# prediction: 3.49, target value: 7.3
# prediction: 20.92, target value: 19.4
# prediction: 24.18, target value: 22.2
# prediction: 9.63, target value: 11.5
# prediction: 16.20, target value: 16.9
# prediction: 16.49, target value: 16.7
# prediction: 16.58, target value: 20.5
# prediction: 26.85, target value: 25.4
# prediction: 14.01, target value: 17.2
# prediction: 20.01, target value: 16.7
# prediction: 28.85, target value: 23.8
# prediction: 23.99, target value: 19.8
# prediction: 16.56, target value: 19.7
# prediction: 20.84, target value: 20.7
# prediction: 14.82, target value: 15.0
# prediction: 3.41, target value: 7.2
# prediction: 8.18, target value: 12.0
# prediction: 1.94, target value: 5.3
# prediction: 22.00, target value: 19.8
# prediction: 20.64, target value: 18.4
# prediction: 21.84, target value: 21.8
# prediction: 14.98, target value: 17.1
# prediction: 18.21, target value: 20.9
# prediction: 9.14, target value: 14.6
# prediction: 9.09, target value: 12.6
# prediction: 12.73, target value: 12.2
# prediction: 6.77, target value: 9.4
# prediction: 14.18, target value: 15.9
# prediction: 2.87, target value: 6.6
# prediction: 14.01, target value: 15.5
# prediction: 3.95, target value: 7.0
# prediction: 18.93, target value: 16.6
# prediction: 11.66, target value: 15.2
# prediction: 22.35, target value: 19.7
# prediction: 8.40, target value: 10.6
# prediction: 3.64, target value: 6.6
# prediction: 6.87, target value: 11.9
# prediction: 19.80, target value: 24.7
# prediction: 6.72, target value: 9.7
# prediction: 1.69, target value: 1.6
# prediction: 23.23, target value: 17.7
# prediction: 1.68, target value: 5.7
# prediction: 20.63, target value: 19.6
# prediction: 6.51, target value: 10.8
# prediction: 5.83, target value: 11.6
# prediction: 3.73, target value: 9.5
# prediction: 25.37, target value: 20.8
# prediction: 5.08, target value: 9.6
# prediction: 16.68, target value: 20.7
# prediction: 7.01, target value: 10.9
# prediction: 19.57, target value: 19.2
# prediction: 20.43, target value: 20.1
# prediction: 9.90, target value: 10.4
# prediction: 9.67, target value: 12.3
# prediction: 11.85, target value: 10.3
# prediction: 20.19, target value: 18.2
# prediction: 23.04, target value: 25.4
# prediction: 4.87, target value: 10.9
# prediction: 5.22, target value: 10.1
# prediction: 24.68, target value: 16.1
# prediction: 11.81, target value: 11.6
# prediction: 17.44, target value: 16.6
# prediction: 16.62, target value: 16.0
# prediction: 16.40, target value: 20.6
# prediction: 0.92, target value: 3.2
# prediction: 10.84, target value: 15.3
# prediction: 13.11, target value: 10.1
# prediction: 3.71, target value: 7.3
# prediction: 12.56, target value: 12.9
# prediction: 15.75, target value: 16.4
# prediction: 9.87, target value: 13.3
# prediction: 16.89, target value: 19.9
# prediction: 14.88, target value: 18.0
# prediction: 10.27, target value: 11.9
# prediction: 22.13, target value: 16.9
# prediction: 3.46, target value: 8.0
# prediction: 17.75, target value: 17.2
# prediction: 20.35, target value: 17.1
# prediction: 23.84, target value: 20.0
# prediction: 5.10, target value: 8.4
# prediction: 15.75, target value: 17.5
# prediction: 2.85, target value: 7.6
# prediction: 14.45, target value: 16.7
# prediction: 18.75, target value: 16.5
# prediction: 25.71, target value: 27.0
# prediction: 22.03, target value: 20.2
# prediction: 15.37, target value: 16.7
# prediction: 23.51, target value: 16.8
# prediction: 14.48, target value: 17.6
# prediction: 13.18, target value: 15.5
# prediction: 18.98, target value: 17.2
# prediction: 5.78, target value: 8.7
# prediction: 27.39, target value: 26.2
# prediction: 22.49, target value: 17.6
# prediction: 18.96, target value: 22.6
# prediction: 12.37, target value: 10.3
# prediction: 17.22, target value: 17.3
# prediction: 24.00, target value: 20.9
# prediction: 2.72, target value: 6.7
# prediction: 4.82, target value: 10.8
# prediction: 6.75, target value: 11.9
# prediction: 2.60, target value: 5.9
# prediction: 15.20, target value: 19.6
# prediction: 13.66, target value: 17.3
# prediction: 3.71, target value: 7.6
# prediction: 8.15, target value: 14.0
# prediction: 15.02, target value: 14.8
# prediction: 26.84, target value: 25.5
# prediction: 19.58, target value: 18.4
# 3.304351994894161
